# %% [markdown]
# # Observation: Simulations and Figures
#
# This notebook contains the code to run the simulations and to create the figures in the paper: "Variability of functional and biodiversity responses to perturbations is predictable and informative" by James A. Orr, Jeremy J. Piggott, Andrew L. Jackson, Michelle C. Jackson and Jean-François Arnoldi.
#
# Code runs for Python 3.9.7 (January 2023).
#
# ### Contents  <a class="anchor" id="1"></a>
# * [Figure 1 - Emperical Data](#2)
# * [Function for simulations](#3)
# * [Figure 2 - Linear Functions](#4)
# * [Figure 3 - Diversity](#5)
# * [Figure 4 - Biomass-Diversity](#6)
# * [Figure 4 - Reproducing empirical results](#7)

# %% [markdown]
# ### Packages and Functions

# %%
from platform import python_version
python_version()
# Out:
# '3.9.7'

# %%
######## General use #############
import numpy as np      
import matplotlib.pyplot as plt                                         
import pandas as pd                                                

####### Specific functions ########
from matplotlib.colors import ListedColormap, LinearSegmentedColormap   # For colour gradients
from numpy.linalg import norm, eig  

####### User-defined functions ########
# Hill diversity
def hill(biomass, hill_n):
    q = hill_n
    positives = np.where(biomass > 1e-10)
    p = biomass[positives]/sum(biomass[positives])
    return np.power(norm(p, q), q/(1.-q))

# Do a and b have the same sign?
def is_mismatched(a,b): 
    if np.sign(a) == np.sign(b):
        return 0 
    else: 
        return 1

####### Colours ########
j_blue = (68/255, 114/255, 255/255)
blue_grad = ["white", j_blue]
blue_cmap = LinearSegmentedColormap.from_list("mycmap", blue_grad)
red_grad = ["white", "red"]
red_cmap = LinearSegmentedColormap.from_list("mycmap", red_grad)

# %% [markdown]
# <br>
# <br>
#
# ## Figure 2 - Emperical Data  <a class="anchor" id="2"></a>
# [Top](#1)

# %%
# Read in the empirical data 
empirical_bio_resp = pd.read_csv("empirical_data/biomass_respiration.csv")
empirical_bio_rich = pd.read_csv("empirical_data/biomass_richness.csv")
empirical_chao_AP = pd.read_csv("empirical_data/chao_AP.csv")

# Create figure 
plt.figure(num=None, figsize=(18, 6.5), dpi=300, facecolor='w', edgecolor='k')


############ Biomass v Respiration ################
plt.subplot(1, 3, 1) 
Max_X = max(abs(empirical_bio_resp['MicrobialBiomass'])) +0.1
Max_Y = max(abs(empirical_bio_resp['Respiration'])) +0.1

plt.scatter(empirical_bio_resp['MicrobialBiomass'], empirical_bio_resp['Respiration'],
           s=25, color=j_blue)
reds = np.where(empirical_bio_resp['mismatch'] == 1)[0]
plt.scatter(empirical_bio_resp['MicrobialBiomass'][reds], empirical_bio_resp['Respiration'][reds],
           s=25, color="red")
plt.xlim(-Max_X, Max_X)
plt.ylim(-Max_Y, Max_Y)

plt.xlabel("Response of Biomass", fontsize = "20")
plt.ylabel("Response of Respiration", fontsize = "20")

plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, Max_X, 0, Max_Y))   
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, Max_X, 0, Max_Y))      
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, -Max_X, 0, -Max_Y))   
plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, -Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.1,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, -Max_X, 0, Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.025,
            extent = (0, -Max_X, 0, Max_Y))  
    
    

    

############ Biomass v Richness ################
plt.subplot(1, 3, 2) 
Max_X = max(abs(empirical_bio_rich['MicrobialBiomass'])) +0.1
Max_Y = max(abs(empirical_bio_rich['OTU'])) +0.1

plt.scatter(empirical_bio_rich['MicrobialBiomass'], empirical_bio_rich['OTU'],
           s=25, color=j_blue)
reds = np.where(empirical_bio_rich['mismatch'] == 1)[0]
plt.scatter(empirical_bio_rich['MicrobialBiomass'][reds], empirical_bio_rich['OTU'][reds],
           s=25, color="red")
plt.xlim(-Max_X, Max_X)
plt.ylim(-Max_Y, Max_Y)

plt.xlabel("Response of Biomass", fontsize = "20")
plt.ylabel("Response of Richness", fontsize = "20")

plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, Max_X, 0, Max_Y))   
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, Max_X, 0, Max_Y))      
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, -Max_X, 0, -Max_Y))   
plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, -Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.1,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, -Max_X, 0, Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.025,
            extent = (0, -Max_X, 0, Max_Y))  



############ Chao v Phosphate ################
plt.subplot(1, 3, 3) 
Max_X = max(abs(empirical_chao_AP['Chao'])) +0.1
Max_Y = max(abs(empirical_chao_AP['AP'])) +0.1

plt.scatter(empirical_chao_AP['Chao'], empirical_chao_AP['AP'],
           s=25, color=j_blue)
reds = np.where(empirical_chao_AP['mismatch'] == 1)[0]
plt.scatter(empirical_chao_AP['Chao'][reds], empirical_chao_AP['AP'][reds],
           s=25, color="red")
plt.xlim(-Max_X, Max_X)
plt.ylim(-Max_Y, Max_Y)

plt.xlabel("Response of Chao index", fontsize = "20")
plt.ylabel("Response of Phosphatase", fontsize = "20")

plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, Max_X, 0, Max_Y))   
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, Max_X, 0, Max_Y))      
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, -Max_X, 0, -Max_Y))   
plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, -Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.1,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, -Max_X, 0, Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.025,
            extent = (0, -Max_X, 0, Max_Y))  



plt.tight_layout(pad=6);

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Function for simulations  <a class="anchor" id="3"></a>
# [Top](#1)

# %%
### Function to generate many communities and perturbations and then compare observations

#    num_funs        = Number of function pairs (and communities) - points on the plots
#    num_exp         = Number of experiments for each function pair - simulations within a point
#    P_d             = Average perturbation direction
#    P_i             = Upper limit of perturbation intensity
#    alpha_low       = Scaling of perturbation by biomass between 0 and 1 (lower bound)  
#    alpha_high      = Scaling of perturbation by biomass between 0 and 1 (higher bound)  


##############################################################

def observation_simulations(num_funs, num_exp, P_d, P_i, alpha_low, alpha_high):
    
    # vectors to fill in 
    ff_prediction = np.zeros(num_funs)
    ff_prediction_div = np.zeros(num_funs)
    dd_prediction = np.zeros(num_funs)
    bd_prediction = np.zeros(num_funs)
    ff_realised = np.zeros(num_funs)
    dd_realised = np.zeros(num_funs)
    bd_realised = np.zeros(num_funs)
    bias = np.zeros(num_funs)
    q_diff = np.zeros(num_funs)
    Unevenness = np.zeros(num_funs)
    diversity = np.zeros(num_funs)
    scaling = np.zeros(num_funs)
    ff_Theta = np.zeros(num_funs)
    ff_Theta_pred = np.zeros(num_funs)
    Richness = np.zeros(num_funs)

    # Loop to create many different communities and functions
    for n in range(num_funs):
        
        # generate S 
        S = np.random.randint(20, 100)              
        
        Richness[n] = S

        # generate community 
        zeta = np.random.uniform(0.5, 2.0)              # unevenness
        Unevenness[n] = zeta                            # store information
        K = np.exp(np.random.normal(0, zeta, size=S))   # Carrying capacity drawn from log normal distribution 
        Nf = np.maximum(K, 0)                           # Equilibrium biomass
        diversity[n] = hill(Nf, 2)                      # Initial diversity (Hill-Simpson)
        
        # Generate a value of alpha, that controls how much stressor is scaled by K 
        alpha = np.random.uniform(alpha_low, alpha_high)
        scaling[n] = alpha

        ######### 1) Comparing observations of linear function ###########
        
        # generate functions
        narrowness_1 = np.random.uniform(0, 1.3)
        narrowness_2 = np.random.uniform(0, 1.3)
        # positive functions
        function_1 = np.exp(np.random.normal(0, narrowness_1, size=S))            
        function_2 = np.exp(np.random.normal(0, narrowness_2, size=S)) 
        # functions with some negative components (supporting figure)
        #function_1 = np.random.normal(0, narrowness_1, size=S)            
        #function_2 = np.random.normal(0, narrowness_2, size=S)

        # functions scaled by K^alpha
        function_1_mod = (K**alpha) * function_1
        function_2_mod = (K**alpha) * function_2

        # measure angle between functions (in radians)
        ff_cos_theta = np.dot(function_1_mod, function_2_mod) / (norm(function_1_mod) * norm(function_2_mod))
        ff_theta = np.arccos(ff_cos_theta)   
        
        # predict angle between functions based on diversity of functions
        ff_predicted_cos_theta = (np.sqrt(hill(function_1, 2) * hill(function_2, 2)))/S              
        ff_predicted_theta = np.arccos(ff_predicted_cos_theta)

        # measure and store prediction of mismatches based on actual angle between function
        ff_prediction[n] = ff_theta/np.pi   
        
        # measure and store prediction of mismatches based on predicted angle between function
        ff_prediction_div[n] = ff_predicted_theta/np.pi     
        
        # store measuted and predicted angles between function 
        ff_Theta[n] = ff_theta
        ff_Theta_pred[n] = ff_predicted_theta

        
        ######### 2) Comparing observations of diversity metrics ###########
        
        # generate diversity indices and their gradients 
        p = K/np.sum(K)  
        q1 = np.random.uniform(0.01, 5)
        q2 = np.random.uniform(0.01, 5)
        d_grad_1 = (np.power(p, q1-1) - np.sum(np.power(p, q1))) * (q1/(1-q1))
        d_grad_2 = (np.power(p, q2-1) - np.sum(np.power(p, q2))) * (q2/(1-q2))
        q_diff[n] = abs(q1-q2) # store the difference in q values of the two diversity metrics

        # diversity gradients scaled by K^alpha
        d_grad_1_mod = (K**alpha) * d_grad_1
        d_grad_2_mod = (K**alpha) * d_grad_2

        # measure angle between diversity indices gradients (in radians)
        dd_cos_theta = np.dot(d_grad_1_mod, d_grad_2_mod) / (norm(d_grad_1_mod) * norm(d_grad_2_mod)) 
        dd_theta = np.arccos(dd_cos_theta)                                               

        # prediction of mismatches based on angle between diversity indices gradients
        dd_prediction[n] = dd_theta/np.pi 
    
        
        ######### 3) Comparing observations of biomass and diversity ########## 
        
        # generate total biomass and gradient of a diversity index 
        p = K/np.sum(K)  
        total = np.ones(S) 
        q = 2  # Hill-Simpson
        d_grad = (np.power(p, q-1) - np.sum(np.power(p, q))) * (q/(1-q))

        # gradients scaled by K^alpha
        total_mod = (K**alpha) * total
        d_grad_mod = (K**alpha) * d_grad

        # measure angle between biomass and gradient of diversity index 
        bd_cos_theta = np.dot(d_grad_mod, total_mod) / (norm(d_grad_mod) * norm(total_mod))    
        bd_theta = np.arccos(bd_cos_theta)                                                

        # prediction of mismatches based on angle between biomass and gradient of diversity index 
        bd_prediction[n] = bd_theta/np.pi 
        
        ### vectors to fill in during second loop ###
        ff_mismatch = np.zeros(num_exp)
        dd_mismatch = np.zeros(num_exp)
        bd_mismatch = np.zeros(num_exp)
        frac = np.zeros(num_exp)

        # Generate a bias for the perturbation at the population level
        P_bias = np.random.uniform(-P_d, P_d)  

        # Loop to run perturbation experiments for each community 
        for m in range(num_exp): 

            ########## Generate Perturbation ##########

            # Perturbation
            P = np.random.normal(P_bias, 1, size=S)  # Draw perturbation from a random normal distribution with a mean direction that introduces a bias
            P = P/norm(P)                            # Normalise so that changing direction does not change intensity
            P_int = np.random.uniform(0, P_i)        # Intensity value to scale entire perbation vector by 
            P = P * P_int * (K**alpha)               # Pertubation multiplied by intensity and scaled by K^alpha
            P = P * np.sqrt(S)                       # Multiply by square root of S so intensity becomes a fraction of each species' K

            ########## Apply Perturbation ##########       
            NP = np.maximum((K - P), 0)                 # Biomass after perturbation 
            DS = NP - Nf                                # Effect of perturbation (at population level)
            frac[m] = len(np.where(DS<0)[0])/len(DS)    # fraction of positive v negative - 0.5 would be unbiased (measure of consistency/bias of perturbation at population-level)

            ######### 1) Linear function ###########
            D_fun_1 = np.dot(function_1, DS)            # observation of function 1 - i.e. projecting vector of change onto function 1
            D_fun_2 = np.dot(function_2, DS)            # observation of function 2 - i.e. projecting vector of change onto function 2
            
            ########## 2) Diversities #########     
            D_q1 = hill(NP, q1) - hill(Nf, q1)          # observation of hill q1
            D_q2 = hill(NP, q2) - hill(Nf, q2)          # observation of hill q2 

            ########## 3) Diversity - Biomass #########   
            D_q = hill(NP, q) - hill(Nf, q)             # observation of diversity metric
            T_1 = sum(NP) - sum(Nf)                     # observation of total biomass  
 
            ########## Mismatches (function returns 1 if mismatch, 0 if consistent) #########
            ff_mismatch[m] = is_mismatched(D_fun_1, D_fun_2)     
            dd_mismatch[m] = is_mismatched(D_q1, D_q2)
            bd_mismatch[m] = is_mismatched(D_q, T_1)
            
        # Actual proportion of mismatches
        ff_realised[n] = np.sum(ff_mismatch)/len(ff_mismatch)    
        dd_realised[n] = np.sum(dd_mismatch)/len(dd_mismatch)
        bd_realised[n] = np.sum(bd_mismatch)/len(bd_mismatch)
        
        # Actual population-level consistency/bias
        bias[n] = abs(0.5 - np.mean(frac))                 

        # Ticker
        if n%100==0:
            print(n)
    
    print("done")
        
    return Richness, ff_prediction, ff_prediction_div, dd_prediction, bd_prediction, ff_realised, dd_realised, bd_realised, bias, q_diff, Unevenness, diversity, scaling, ff_Theta, ff_Theta_pred

# %%
num_funs = 1000   # number of function pairs 
num_exp = 500     # number of perturbations per function pair
P_d = 0.3         # perturbation direction
P_i = 0.1         # perturbation intensity
alpha_low = 0     # scaling (lower end of random normal for scaling non-add by biomass)
alpha_high = 0    # scaling (upper end of random normal for scaling non-add by biomass)

Richness, ff_prediction, ff_prediction_div, dd_prediction, bd_prediction, ff_realised, dd_realised, bd_realised, bias, q_diff, Unevenness, diversity, scaling, ff_Theta, ff_Theta_pred = observation_simulations(num_funs, num_exp, P_d, P_i, alpha_low, alpha_high)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# done

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Figure 2 - Linear Functions  <a class="anchor" id="4"></a>
# [Top](#1)

# %%
grad = [(0, 0, 0), (1, 1, 1)]
cmap = LinearSegmentedColormap.from_list("cmap", grad)

plt.figure(num=None, figsize=(5.5, 5), dpi=300, facecolor='w', edgecolor='k')

X = np.sort(ff_prediction)
plt.plot(X, X, 'k', lw=2, linestyle = '--', alpha = 1)
plt.scatter(ff_prediction, ff_realised, c = bias, s = 7.5, cmap = cmap, edgecolors='k', linewidths=0.05)
plt.xlabel("theta/pi")
plt.ylabel("Proportion of mismatches")
plt.colorbar(label="Population-level consistency")
plt.title(label="Linear functions");

# %%
plt.figure(num=None, figsize=(2, 2), dpi=180, facecolor='w', edgecolor='k')


plt.scatter(ff_Theta_pred, ff_Theta, s = 2, edgecolors='k', linewidths=0.05, color = "k", alpha = 0.5)
plt.ylabel("theta", fontsize=8)
plt.xlabel("predicted theta", fontsize=8)
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4);

# %% [markdown]
# - The proportion of mismatches between two linear (and positive) functions can be predicted using the angle between those functions divided by pi. This only holds true when the population-level non-additivity is unbiased - in other words, half the species respond synergistically and half the sepecies respond antagonistically. When there is a bias at the population level (due to whatever reason), there will be less mismatches between functions that predicted by their angles. Even a 60:40 split between antagonism and synergism will lead to an underestimation of the proportion of mismatches. This geometric effect can be easily visualised in 2D.
#
# - The angle between the two functions can be predicted by measuring the diversity of the two functions, which is  far more easily accesible in empirical data than the precise angle itself.
#
# - With two of the three variables, 1. angle between functions, 2. mismatches between functions, and 3. population bias of non-additivity, we can say something about the third variable. Therefore, mismatches between functions can give us insights into the underlying population-level non-additivity.
#
# - When non-additivity is relative to biomass, we need to modify the angles between functions by modifying the functions themselves.
#
# - Stressor direction and stressor intensity (unless there are extinctions) have no effect here. If extinctions occur (negative stressors and high intensity) non-additivity will be very biased so the angle between functions will overestimate the actual proportion of mismatches.

# %% [markdown]
# **Figure 5(A)**

# %%
grad = [(0, 0, 0), (1, 1, 1)]
cmap = LinearSegmentedColormap.from_list("cmap", grad)

plt.figure(num=None, figsize=(5.5, 5), dpi=300, facecolor='w', edgecolor='k')

plt.scatter((ff_prediction-ff_realised)/ff_prediction, bias, c = Richness, s = 7.5, cmap = cmap, edgecolors='k', linewidths=0.05)
plt.ylabel("Population-level consistency")
plt.xlabel("Relative Deviation")
plt.colorbar(label="Species Richness");

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Figure 3 - Diversity  <a class="anchor" id="5"></a>
# [Top](#1)

# %%
plt.figure(num=None, figsize=(5.5, 5), dpi=300, facecolor='w', edgecolor='k')

X = np.sort(dd_prediction)
plt.plot(X, X, 'k', lw=2, linestyle = '--', alpha = 1)
plt.scatter(dd_prediction, dd_realised, c = bias, s = (q_diff*2)**1.5,  
            cmap = cmap, edgecolors='k', linewidths=0.05)
plt.xlabel("theta/pi")
plt.ylabel("Proportion of mismatches")
plt.colorbar(label="Population-level consistency")
plt.title(label="Diversity");

ax = plt.gca()

#make a legend:
pws = [0, 1, 2, 4]
for pw in pws:
    plt.scatter([], [], s= (pw*2)**1.5, c="k",label=str(pw))

h, l = plt.gca().get_legend_handles_labels()
plt.legend(h[1:], l[1:], labelspacing=1.0, title="q_diff", borderpad=1, 
            frameon=True, framealpha=0.6, edgecolor="k", facecolor="w");

# %% [markdown]
# - Mismatches between the observations of diversity functions can be quite well explained by the angles between their gradients. The angles between these gradients increase as the difference between the q numbers of the diversity indices increases.
#
# - Interestingly, diversity gradients are actually very similar to positive functions, especially when evenness is low. When increases in the more dominant species will decrease diversity but all the others will increase diversity. On the other hand, when eveness is high, increases to most species will decrease diversity so there will be many negative components to the diversity gradient.
#
# - As these functions behave similarly to positive functions, the role of bias is similar - bias means that non-additivity is more likely to fall in the quadrants that are purely positive or purely negativem, which for postive functions, is exactly where the cone of mismatches isn't! There will be a systematic overestimation of the proportion of mismatches.
#
# - When non-additivity is proportional to biomass, then the most non-additivity is focused on the negative components of the diversity gradients! This means that the bias will not have the same effect that it had for positive functions. So multiplying non-add by K hides the effect of bias.

# %%
plt.figure(num=None, figsize=(4.5, 2), dpi=180, facecolor='w', edgecolor='k')

plt.subplot(1, 2, 1) 
plt.scatter(q_diff, dd_realised, s = 2, edgecolors='k', linewidths=0.05, color = "k", alpha = 0.5)
plt.ylabel("realised mismatches", fontsize=8)
plt.xlabel("q_diff", fontsize=8)
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4);

plt.subplot(1, 2, 2) 
plt.scatter(diversity, dd_realised, s = 2, edgecolors='k', linewidths=0.05, color = "k", alpha = 0.5)
plt.ylabel("realised mismatches", fontsize=8)
plt.xlabel("initial diversity", fontsize=8)
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
plt.locator_params(axis='x', nbins=4)
plt.locator_params(axis='y', nbins=4);

plt.tight_layout(pad=2);

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Figure 4 - Biomass-Diversity  <a class="anchor" id="6"></a>
# [Top](#1)

# %%
## Allow perturbation to be scaled by biomass now ** 

num_funs = 1000   # number of function pairs 
num_exp = 500     # number of perturbations per function pair
P_d = 0.3         # perturbation direction
P_i = 0.1         # perturbation intensity
alpha_low = 0     # scaling (lower end of random normal for scaling non-add by biomass)
alpha_high = 1    # scaling (upper end of random normal for scaling non-add by biomass)


Richness, ff_prediction, ff_prediction_div, dd_prediction, bd_prediction, ff_realised, dd_realised, bd_realised, bias, q_diff, Unevenness, diversity, scaling, ff_Theta, ff_Theta_pred = observation_simulations(num_funs, num_exp, P_d, P_i, alpha_low, alpha_high)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# done

# %%
plt.figure(num=None, figsize=(5.5, 5), dpi=300, facecolor='w', edgecolor='k')

X = np.sort(bd_prediction)
plt.plot(X, X, 'k', lw=2, linestyle = '--', alpha = 1)
plt.scatter(bd_prediction, bd_realised, c = bias, s = ((1+scaling)*1.25)**3,  
            cmap = cmap, edgecolors='k', linewidths=0.05)
plt.xlabel("theta/pi")
plt.ylabel("Proportion of mismatches")
plt.colorbar(label="Population-level consistency")
plt.title(label="Biomass-Diversity");

ax = plt.gca()

#make a legend:
pws = [0, 0, 0.5, 1]
for pw in pws:
    plt.scatter([], [], s = ((1+pw)*1.25)**3, c="k",label=str(pw))

h, l = plt.gca().get_legend_handles_labels()
plt.legend(h[1:], l[1:], labelspacing=1.0, title="alpha", borderpad=1, 
            frameon=True, framealpha=0.6, edgecolor="k", facecolor="w");

#plt.axhline(y=0.5, color='r', linestyle='-', alpha =0.2, lw=4);

# %% [markdown]
# - Looking at the mismatches between biomass and diversity is very revealing. It actually illuminates another piece of the puzzle, another piece of information about the non-additivity at the population level that is relevant the mismatches of observations at the community level: the scaling of non-additivity by the biomass of species.
#
# - It is important to modify the function (total biomass) and the diversity gradient by multiplying by K^alpha to get the most informative angle. When you don't do this, there is quite a lot of weirdness (funnel effects), related to the eveness of the community and the non-linearity of the diversity function.
#
# - When non-additivity is relative to biomass, it means that diversity will be very much acting like a negative function. When you compare the negative function with the positive function of total biomass, we see that the angle between the diversity gradient and linear function can exceed 90 degrees! This means that when non-additivity is unbaised there will be systematic mismatches. We can go above 0.5 (which is what we had originally seen in the empirical data).
#
# - Alpha, how much non-additivity is scaled by biomass, does a very good job oof predicting the angle between biomass and diversity (seen by the gradient of the size of the points). The effect of bias can still be seen nicely.

# %% [markdown]
# **Figure 5(B)**

# %%
grad = [(0, 0, 0), (1, 1, 1)]
cmap = LinearSegmentedColormap.from_list("cmap", grad)

plt.figure(num=None, figsize=(5.5, 5), dpi=300, facecolor='w', edgecolor='k')

plt.scatter(bd_realised, scaling,  c = bias, s = 7.5, cmap = cmap, edgecolors='k', linewidths=0.05)
plt.ylabel("Biomass Scaling Exponent")
plt.xlabel("Realised Proportion of Mismatches")
plt.colorbar(label="Population-level consistency");

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Figure 4 - Reproducing empirical results  <a class="anchor" id="7"></a>
# [Top](#1)

# %%
num_exp = 1000 
S = 50
P_d = 0.3
P_i = 0.1
P_bias = 0

# vectors to fill in 
D_biomass = np.zeros(num_exp)
D_diversity = np.zeros(num_exp)
mismatch = np.zeros(num_exp)
bd_prediction = np.zeros(num_exp)

# Loop to run stressor experiments for each community 
for m in range(num_exp): 
        
    # generate scaling
    alpha = np.random.uniform(0.5, 1)
    
    # generate community 
    S = np.random.randint(20, 100)
    zeta = np.random.uniform(0.5, 2.5)      # unevenness
    K = np.exp(np.random.normal(0, zeta, size=S))    
    Nf = np.maximum(K, 0)
    p = K/np.sum(K)

    # generate total biomass 
    total = np.ones(S) 
    total_mod = (K**alpha) * total
    
    # generate diversity 
    q = np.random.uniform(0.01, 2)
    d_grad = (np.power(p, q-1) - np.sum(np.power(p, q))) * (q/(1-q))
    d_grad_mod = (K**alpha) * d_grad

    # generate perturbation
    P = np.random.normal(P_bias, 1, size=S)  # Draw perturbation from a random normal distribution with a mean direction
    P = P/norm(P)                            # Normalise so that changing direction does not change intensity
    P_int = np.random.uniform(0, P_i)        # Intensity value to scale entire perbation vector by 
    P = P * P_int * (K**alpha)               # Pertubation multiplied by intensity and scaled by K^alpha
    P = P * np.sqrt(S)                       # Multiply by square root of S so intensity becomes a fraction of each species' K

    ########## apply perturbation ##########       
    NP = np.maximum((K - P), 0)        # biomass after perturbation
    D_q = hill(NP, q) - hill(Nf, q)    # observation of diversity
    D_diversity[m] = D_q               
    D_T = sum(NP) - sum(Nf)            # observation of total biomass
    D_biomass[m] = D_T                
    
    # Mismatches
    mismatch[m] = is_mismatched(D_T, D_q)  # 1 is mismatch, 0 if same sign

# %%
grad = [j_blue, "red"]
cmap = LinearSegmentedColormap.from_list("cmap", grad)

plt.figure(num=None, figsize=(6.5, 6.5), dpi=300, facecolor='w', edgecolor='k')


# Biomass v Diversity
Max_X = np.percentile(D_biomass, 99) #max(D_biomass)
Max_Y = np.percentile(D_diversity, 99) #max(D_diversity)
#Max_X = max(D_biomass)
#Max_Y = max(D_diversity)

plt.scatter(D_biomass, D_diversity,
           s=5, c=mismatch, cmap = cmap)
plt.xlim(-Max_X, Max_X)
plt.ylim(-Max_Y, Max_Y)


plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, Max_X, 0, Max_Y))   
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, Max_X, 0, Max_Y))      
plt.imshow([[0.,1.], [0.,1.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.5,
            extent = (0, -Max_X, 0, -Max_Y))   
plt.imshow([[1.,1.], [0.,0.]],
            cmap = blue_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.25,
            extent = (0, -Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.1,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, Max_X, 0, -Max_Y)) 
plt.imshow([[1.,1.], [0.,0.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.05,
            extent = (0, -Max_X, 0, Max_Y)) 
plt.imshow([[0.,1.], [0.,1.]],
            cmap = red_cmap, 
            interpolation = 'quadric',
            aspect = 'auto',
            alpha = 0.025,
            extent = (0, -Max_X, 0, Max_Y));  

print(np.sum(mismatch)/len(mismatch)) # Proportion of mismatch

plt.xlabel("Response of Biomass")
plt.ylabel("Response of Diversity");
# Out:
# 0.648
